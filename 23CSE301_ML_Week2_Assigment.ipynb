# %% [markdown]
# **Enter your code for Exercise 1 in the following cells (add as many cell as you need)**
#
# ---

# %%
import pandas as pd

df = pd.read_csv('Iris.csv')

# %%
print("HEAD")
print(df.head(10))
print("\nLAST ROWS")
print(df.tail(5))
# Out:
# HEAD
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
#
# LAST ROWS
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# ...

# %%
print("SUMMARY STATISTICS")
print(df.describe())
print("\nDATA TYPES")
print(df.dtypes)
# Out:
# SUMMARY STATISTICS
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
# DATA TYPES
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df[df['Id']>140]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df['sepal_sum'] = df['SepalLengthCm'] + df['SepalWidthCm']
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_sum
# 0        8.6
# 1        7.9
# 2        7.9
# 3        7.7
# 4        8.6

# %%
df.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm  sepal_sum
# Species
# Iris-setosa             0.244      8.424
# Iris-versicolor         1.326      8.706
# Iris-virginica          2.026      9.562

# %%
df.sort_values('SepalWidthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0           2.0            3.5           1.0
# 62    63            6.0           2.2            4.0           1.0
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 16    17            5.4           3.9            1.3           0.4
# 14    15            5.8           4.0            1.2           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 15    16            5.7           4.4            1.5           0.4
#
#              Species  sepal_sum
# 60   Iris-versicolor        7.0
# 62   Iris-versicolor        8.2
# 119   Iris-virginica        8.2
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# sepal_sum        0
# dtype: int64

# %%
df.to_csv('modified.csv')

# %% [markdown]
# **Enter your code for Exercise 2 in the following cells (add as many cell as you need)**
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['PetalLengthCm'],bins=10,color='turquoise')
plt.show()

# %%
sns.boxplot(x='PetalWidthCm', y='Id', data=df[:30],color='maroon')
plt.show()

# %%
sns.scatterplot(x='PetalLengthCm', y='Id',hue='PetalLengthCm', data=df)
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.pairplot(df[['Id', 'SepalLengthCm', 'Species']], hue='Species')
plt.show()
